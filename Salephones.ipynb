# %%
import pandas as pd

# %%
df=pd.read_csv('Sales.csv')

# %%
df.head()
# Out:
#     Brands        Models         Colors Memory Storage Camera  Rating  \
# 0  SAMSUNG  GALAXY M31S    Mirage Black   8 GB  128 GB    Yes     4.3
# 1    Nokia           3.2          Steel   2 GB   16 GB    Yes     3.8
# 2   realme           C2   Diamond Black   2 GB     NaN    Yes     4.4
# 3  Infinix        Note 5       Ice Blue   4 GB   64 GB    Yes     4.2
# 4    Apple    iPhone 11           Black    4GB   64 GB    Yes     4.6
#
#    Selling Price  Original Price                Mobile  Discount  \
# 0          19330           20999  SAMSUNG GALAXY M31S       1669
# 1          10199           10199             Nokia 3.2         0
# 2           6999            7999            realme C2       1000
# 3          12999           12999        Infinix Note 5         0
# 4          49900           49900      Apple iPhone 11          0
#
#    discount percentage
# 0             7.947998
# 1             0.000000
# 2            12.501563
# 3             0.000000
# 4             0.000000

# %%
 df.sort_values(by='Selling Price')
# Out:
#        Brands              Models       Colors Memory Storage Camera  Rating  \
# 1501    Nokia                 105        Black   4 MB    4 MB    Yes     4.3
# 2054    Nokia        Ta -1010/105        Black   4 MB    4 MB    Yes     4.2
# 2487   GIONEE                 S96        Black   8 MB   16 MB    Yes     3.7
# 978    GIONEE                L700        Black   8 MB   16 MB    Yes     3.9
# 1338  SAMSUNG       GT 1200 R/I/M        Black    NaN    2 MB    Yes     4.1
# ...       ...                 ...          ...    ...     ...    ...     ...
# 831     Apple   iPhone 13 Pro Max         Gold    4GB    1 TB    Yes     4.7
# 1079    Apple  iPhone 13 Pro Max          Gold   6 GB     NaN    Yes     NaN
# 2032    Apple  iPhone 13 Pro Max      Graphite   6 GB    1 TB    Yes     NaN
# 903     Apple   iPhone 13 Pro Max       Silver    4GB    1 TB    Yes     4.7
# 799     Apple   iPhone 13 Pro Max  Sierra Blue    4GB    1 TB    Yes     4.7
#
# ...

# %%
df['Selling Price'].max()
# Out:
# 179900

# %%
df['Selling Price'].min()
# Out:
# 1000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3114 entries, 0 to 3113
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Brands               3114 non-null   object
#  1   Models               3114 non-null   object
#  2   Colors               3114 non-null   object
#  3   Memory               3071 non-null   object
#  4   Storage              3075 non-null   object
#  5   Camera               3114 non-null   object
#  6   Rating               2970 non-null   float64
#  7   Selling Price        3114 non-null   int64
#  8   Original Price       3114 non-null   int64
#  9   Mobile               3114 non-null   object
#  10  Discount             3114 non-null   int64
#  11  discount percentage  3114 non-null   float64
# dtypes: float64(2), int64(3), object(7)
# memory usage: 292.1+ KB

# %%
df.describe()
# Out:
#             Rating  Selling Price  Original Price      Discount  \
# count  2970.000000    3114.000000     3114.000000   3114.000000
# mean      4.243098   26436.625562    28333.473025   1896.847463
# std       0.271991   30066.892622    31525.599889   5337.126176
# min       2.300000    1000.000000     1000.000000  -8000.000000
# 25%       4.100000    9990.000000    10030.250000      0.000000
# 50%       4.300000   15000.000000    16889.500000      0.000000
# 75%       4.400000   28999.000000    31500.000000   2000.000000
# max       5.000000  179900.000000   189999.000000  75000.000000
#
#        discount percentage
# count          3114.000000
# mean              6.086788
# std              11.106776
# min            -160.320641
# 25%               0.000000
# 50%               0.000000
# 75%               9.836388
# max              70.610305

# %% [markdown]
# ### To find missing values in Database

# %%
df.isna().sum()
# Out:
# Brands                   0
# Models                   0
# Colors                   0
# Memory                  43
# Storage                 39
# Camera                   0
# Rating                 144
# Selling Price            0
# Original Price           0
# Mobile                   0
# Discount                 0
# discount percentage      0
# dtype: int64

# %% [markdown]
# ## Plotting Graph of Rating

# %%
df.Rating.plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df.Rating.median()
# Out:
# 4.3

# %%
df.Rating.fillna(df.Rating.median(),inplace=True)

# %%
df.isna().sum()
# Out:
# Brands                  0
# Models                  0
# Colors                  0
# Memory                 43
# Storage                39
# Camera                  0
# Rating                  0
# Selling Price           0
# Original Price          0
# Mobile                  0
# Discount                0
# discount percentage     0
# dtype: int64

# %%
df.Memory.mode()[0]
# Out:
# '4 GB'

# %%
df.Memory.fillna(df.Memory.mode()[0],inplace=True)

# %%
df.isna().sum()
# Out:
# Brands                  0
# Models                  0
# Colors                  0
# Memory                  0
# Storage                39
# Camera                  0
# Rating                  0
# Selling Price           0
# Original Price          0
# Mobile                  0
# Discount                0
# discount percentage     0
# dtype: int64

# %%
df.Storage.mode()[0]
# Out:
# '64 GB'

# %%
df.Storage.fillna(df.Storage.mode()[0],inplace=True)

# %%
df.isna().sum()
# Out:
# Brands                 0
# Models                 0
# Colors                 0
# Memory                 0
# Storage                0
# Camera                 0
# Rating                 0
# Selling Price          0
# Original Price         0
# Mobile                 0
# Discount               0
# discount percentage    0
# dtype: int64

# %% [markdown]
# ## Importing Library for Visualisation

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.hist(df.Rating)
# Out:
# (array([   2.,    5.,    8.,   11.,   56.,  315.,  461., 1675.,  571.,
#           10.]),
#  array([2.3 , 2.57, 2.84, 3.11, 3.38, 3.65, 3.92, 4.19, 4.46, 4.73, 5.  ]),
#  <BarContainer object of 10 artists>)

# %%
df.Camera.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Camera'>

# %%
plt.hist(df.Discount)
# Out:
# (array([1.977e+03, 1.015e+03, 4.900e+01, 2.200e+01, 3.300e+01, 8.000e+00,
#         6.000e+00, 1.000e+00, 1.000e+00, 2.000e+00]),
#  array([-8000.,   300.,  8600., 16900., 25200., 33500., 41800., 50100.,
#         58400., 66700., 75000.]),
#  <BarContainer object of 10 artists>)

# %%
plt.figure(figsize=(6, 20))
plt.boxplot(df['Original Price'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x23d1a3a50d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x23d1a3a62d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x23d1a3a4850>],
#  'medians': [<matplotlib.lines.Line2D at 0x23d1a3a7290>],
#  'fliers': [<matplotlib.lines.Line2D at 0x23d1a3a7910>],
#  'means': []}

# %%
plt.figure(figsize=(10, 6))

df['Selling Price'].plot(kind='kde',y='Brands')
# Out:
# <Axes: ylabel='Density'>

# %%
import seaborn as sns

# %%
plt.figure(figsize=(20, 10))
sns.scatterplot(df,x='Memory',y='Original Price')
# Out:
# <Axes: xlabel='Memory', ylabel='Original Price'>

# %%
df.corr(numeric_only=True)
# Out:
#                        Rating  Selling Price  Original Price  Discount  \
# Rating               1.000000       0.413764        0.413119  0.109280
# Selling Price        0.413764       1.000000        0.986097  0.191189
# Original Price       0.413119       0.986097        1.000000  0.351638
# Discount             0.109280       0.191189        0.351638  1.000000
# discount percentage  0.050404      -0.066082        0.049209  0.662945
#
#                      discount percentage
# Rating                          0.050404
# Selling Price                  -0.066082
# Original Price                  0.049209
# Discount                        0.662945
# discount percentage             1.000000

# %%
sns.heatmap(df.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >

# %%
brand_counts = df['Brands'].value_counts().sort_index()

brand_counts.plot(kind='barh', color='skyblue')
# Out:
# <Axes: ylabel='Brands'>
